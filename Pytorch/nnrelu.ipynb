# %%
import torch
from torch import nn
from torch.nn import ReLU

input = torch.tensor([[1, -0.5],
                      [-1, 3]])

output = torch.reshape(input, (-1, 1, 2, 2))
print(output.shape)

class MyModule(nn.Module):
    pass

# %% [markdown]
# ![1687693403182.png](attachment:1687693403182.png)
